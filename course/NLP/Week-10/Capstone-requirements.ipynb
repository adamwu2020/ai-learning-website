# %% [markdown]
# # Capstone Project: SmartReview — Customer Review Intelligence System
# ### NLP Course 2027 — Week 10
#
# ---
#
# ## Project Overview
#
# You are building **SmartReview**, an end-to-end NLP pipeline for an e-commerce platform. The platform has 200 customer reviews across 25 products in 5 categories (Electronics, Clothing, Books, Home & Kitchen, Sports & Outdoors).
#
# Your goal is to extract actionable intelligence from these reviews: sentiment, aspects, topics, entities, and product similarity — and package the results in a deployable system.
#
# **Dataset:** `dataset.csv` (200 reviews, 11 columns)
#
# | Column | Description |
# |--------|-------------|
# | `review_id` | Unique review identifier |
# | `product_id` | Product identifier (P001–P025) |
# | `product_name` | Product name |
# | `category` | Electronics / Clothing / Books / Home / Sports |
# | `rating` | Star rating 1–5 |
# | `review_title` | Short review title |
# | `review_text` | Full review text |
# | `helpful_votes` | Number of users who found the review helpful |
# | `verified_purchase` | Whether purchase was verified |
# | `date` | Review date (YYYY-MM-DD) |
# | `sentiment_label` | Ground-truth sentiment: positive / negative / neutral |
#
# ---
#
# ## Course Skills Covered
#
# | Task | Weeks |
# |------|-------|
# | Text preprocessing & vocabulary analysis | 1–2 |
# | Frequency distributions & corpus statistics | 1–2 |
# | Text classification (TF-IDF + ML) | 3 |
# | Sequence tagging & NER | 4, 6 |
# | Information extraction (aspects, keyphrases) | 4 |
# | Word embeddings & semantic similarity | 5 |
# | Topic modeling (LDA) | 8 |
# | Transformer fine-tuning | 6–7 |
# | Production system design | 9 |

# %%
# Setup — run first
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk

for pkg in ['punkt', 'punkt_tab', 'stopwords', 'wordnet', 'averaged_perceptron_tagger',
            'averaged_perceptron_tagger_eng', 'maxent_ne_chunker',
            'maxent_ne_chunker_tab', 'words']:
    nltk.download(pkg, quiet=True)

df = pd.read_csv('dataset.csv')
print(f'Dataset loaded: {len(df)} reviews')
print(df.head(3).to_string())

# %% [markdown]
# ---
# ## Task 1: Exploratory Data Analysis (Weeks 1–2)
#
# **Objectives:**
# - Understand the dataset distribution
# - Compute vocabulary and text statistics
# - Visualize rating and sentiment distributions
#
# **Requirements:**
# 1. Plot the distribution of ratings and sentiment labels (bar charts)
# 2. Plot the distribution of reviews per category
# 3. Compute: total tokens, vocabulary size, lexical diversity, and average review length per category
# 4. Plot the top 20 most frequent words across all reviews (after stopword removal)
# 5. Create a word frequency comparison between positive and negative reviews — what words distinguish them?

# %%
# Task 1: YOUR CODE HERE
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk import FreqDist

stop_words = set(stopwords.words('english'))

# 1. Plot rating and sentiment distributions

# 2. Reviews per category

# 3. Vocabulary statistics per category

# 4. Top 20 content words

# 5. Positive vs negative word comparison

# %% [markdown]
# ---
# ## Task 2: Text Preprocessing Pipeline (Week 2)
#
# **Objectives:**
# - Build a reusable preprocessing pipeline for review text
#
# **Requirements:**
# 1. Implement a `preprocess_review(text)` function that: lowercases, removes punctuation, tokenizes, removes stopwords, and lemmatizes
# 2. Apply it to the full dataset and store in a new column `clean_text`
# 3. Show before/after for 3 example reviews
# 4. Report how many tokens are removed at each pipeline stage (punctuation removal → stopword removal → lemmatization effect)

# %%
# Task 2: YOUR CODE HERE
import string
from nltk.stem import WordNetLemmatizer

def preprocess_review(text):
    """Full preprocessing pipeline for review text."""
    # YOUR CODE HERE
    pass

# Apply to dataset
# df['clean_text'] = df['review_text'].apply(preprocess_review)

# Show before/after examples

# Token count statistics at each stage

# %% [markdown]
# ---
# ## Task 3: Sentiment Classification (Weeks 3, 6–7)
#
# **Objectives:**
# - Build and evaluate sentiment classifiers
# - Compare classical ML with transformer approaches
#
# **Requirements:**
# 1. Split the data 80/20 train/test (stratified by `sentiment_label`)
# 2. Train and evaluate **Baseline**: TF-IDF (unigrams + bigrams) + Logistic Regression
# 3. Train and evaluate **Improved**: TF-IDF + best classifier from your experimentation
# 4. Report: accuracy, precision, recall, F1 per class, confusion matrix
# 5. **(Bonus)** Use a zero-shot classifier (e.g., `facebook/bart-large-mnli`) and compare
# 6. Perform error analysis: show 5 misclassified reviews and explain why the model got them wrong

# %%
# Task 3: YOUR CODE HERE
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# 1. Train/test split

# 2. TF-IDF + LR baseline

# 3. Improved model

# 4. Evaluation metrics and confusion matrix

# 5. (Bonus) Zero-shot transformer

# 6. Error analysis

# %% [markdown]
# ---
# ## Task 4: Aspect-Based Sentiment Analysis (Week 4)
#
# **Objectives:**
# - Extract product aspects from reviews
# - Assign sentiment to each aspect
#
# **Requirements:**
# 1. Define an aspect lexicon covering at least 8 aspects:
#    `quality`, `price`, `battery`, `shipping`, `comfort`, `design`, `service`, `durability`
# 2. For each review, detect which aspects are mentioned (keyword matching + regex)
# 3. Assign a sentiment score (+1 / -1 / 0) to each detected aspect based on surrounding context words
# 4. Compute per-aspect average sentiment across the dataset
# 5. Plot: which aspects are most frequently mentioned? Which have the worst average sentiment?
# 6. Which category has the most negative price sentiment? Which has the best quality sentiment?

# %%
# Task 4: YOUR CODE HERE
import re
from collections import defaultdict

ASPECT_KEYWORDS = {
    'quality':    ['quality', 'build', 'material', 'construction', 'made', 'durable', 'durability'],
    'price':      ['price', 'cost', 'expensive', 'cheap', 'value', 'worth', 'overpriced', 'affordable'],
    'battery':    ['battery', 'charge', 'charging', 'power', 'life', 'hours'],
    'shipping':   ['shipping', 'delivery', 'arrived', 'package', 'packaging', 'shipped'],
    'comfort':    ['comfort', 'comfortable', 'fit', 'wear', 'soft', 'cushion', 'cozy'],
    'design':     ['design', 'look', 'style', 'appearance', 'aesthetic', 'color', 'beautiful'],
    'service':    ['service', 'support', 'customer', 'return', 'refund', 'response', 'helpful'],
    'durability': ['broke', 'broken', 'lasted', 'cracked', 'snapped', 'fell apart', 'stopped working'],
}

# YOUR CODE: detect aspects and assign sentiment
# YOUR CODE: aggregate and visualize

# %% [markdown]
# ---
# ## Task 5: Named Entity Extraction (Week 4)
#
# **Objectives:**
# - Extract brand names and organizations mentioned in reviews
#
# **Requirements:**
# 1. Use NLTK `ne_chunk` to extract all named entities from all reviews
# 2. Also use regex to extract known brand names: `Apple, Samsung, Nike, Adidas, Sony, Bose, JBL, Roomba, Salomon, Merrell, Nike, Garmin, Fitbit, Wilson, Gore-Tex`
# 3. Build a brand mention frequency table
# 4. For each brand, calculate what fraction of mentions appear in negative reviews
# 5. Which brands are most associated with negative reviews? With positive?

# %%
# Task 5: YOUR CODE HERE
from nltk import ne_chunk, pos_tag, word_tokenize

KNOWN_BRANDS = [
    'Apple', 'Samsung', 'Nike', 'Adidas', 'Sony', 'Bose', 'JBL',
    'Roomba', 'Salomon', 'Merrell', 'Garmin', 'Fitbit', 'Wilson',
    'Gore-Tex', 'Nespresso', 'Vibram', 'HEPA'
]

# YOUR CODE: extract entities with NLTK NE chunker

# YOUR CODE: extract known brand mentions with regex

# YOUR CODE: brand frequency and sentiment association table

# %% [markdown]
# ---
# ## Task 6: Topic Modeling (Week 8)
#
# **Objectives:**
# - Discover latent themes in customer reviews using LDA
#
# **Requirements:**
# 1. Preprocess reviews and build a document-term matrix (CountVectorizer)
# 2. Train LDA with `n_components=8` topics
# 3. Print the top 10 words for each topic
# 4. Assign each review its dominant topic
# 5. Name each topic based on its top words (e.g., Topic 0 = "Comfort & Fit", Topic 1 = "Battery & Electronics")
# 6. Compare topic distribution across product categories — does Electronics dominate tech topics? Books dominate content topics?
# 7. Plot: topic distribution as a stacked bar chart per category

# %%
# Task 6: YOUR CODE HERE
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# 1. Build document-term matrix

# 2. Train LDA

# 3. Print top words per topic

# 4. Assign dominant topic to each review

# 5. Name topics

# 6-7. Category topic distribution

# %% [markdown]
# ---
# ## Task 7: Review Similarity & Product Recommendation (Weeks 5, 8)
#
# **Objectives:**
# - Find semantically similar reviews
# - Build a content-based product recommender
#
# **Requirements:**
# 1. Build TF-IDF vectors for all reviews; given a query review, find the 3 most similar reviews
# 2. Aggregate review vectors per product (mean TF-IDF); find the 3 most similar products for any query product
# 3. Build a product recommendation function `recommend_products(product_name, n=3)` that returns similar products with similarity scores
# 4. Test with: `'Wireless Headphones'`, `'Hiking Boots'`, `'Atomic Habits'`
# 5. **(Bonus)** Re-do product similarity using Word2Vec embeddings (train on this corpus) and compare results with TF-IDF

# %%
# Task 7: YOUR CODE HERE
from sklearn.metrics.pairwise import cosine_similarity

# 1. Review-level similarity search

# 2-3. Product-level recommendation function

def recommend_products(product_name, n=3):
    """Return n most similar products based on review content."""
    # YOUR CODE HERE
    pass

# 4. Test recommendations
for product in ['Wireless Headphones', 'Hiking Boots', 'Atomic Habits']:
    print(f'Because you viewed "{product}":')
    recs = recommend_products(product)
    # print results

# %% [markdown]
# ---
# ## Task 8: Insights Report & Production Design (Week 9)
#
# **Objectives:**
# - Synthesize findings into actionable business insights
# - Design a production-ready API
#
# **Requirements:**
# 1. **Product Health Dashboard**: For each of the 25 products, compute: average rating, sentiment score (% positive), most common negative aspect, top 3 keywords from positive reviews, top 3 keywords from negative reviews
# 2. **Flagged Products**: Identify products where >40% of reviews are negative — these need attention
# 3. **API Design**: Write a FastAPI endpoint `/analyze` that accepts a review text and returns: sentiment, detected aspects with sentiment, extracted entities, and top 3 similar products
# 4. **Evaluation Plan**: Define 3 metrics you would monitor in production (e.g., sentiment drift, aspect coverage, model accuracy over time)
# 5. **Written Summary** (markdown cell): 200-word business summary of findings including the most actionable insights for the e-commerce platform

# %%
# Task 8.1-8.2: Product Health Dashboard
# YOUR CODE HERE

def product_health_report(product_name):
    """Return health metrics for a single product."""
    # YOUR CODE HERE
    pass

# Generate dashboard for all 25 products
# Flag products with >40% negative reviews

# %%
# Task 8.3: FastAPI /analyze endpoint
# Write the full API code below (does not need to run in notebook)

api_code = '''
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI(title="SmartReview API")

class ReviewRequest(BaseModel):
    text: str
    product_name: str = None

@app.post("/analyze")
async def analyze_review(req: ReviewRequest):
    # YOUR CODE: return sentiment, aspects, entities, similar products
    pass
'''
print(api_code)

# %% [markdown]
# ### Task 8.4 — Production Monitoring Plan
#
# Define 3 metrics you would monitor in production. For each metric specify:
# - What it measures
# - How you compute it
# - What threshold triggers an alert
#
# **YOUR ANSWER HERE**
#
# ---
#
# ### Task 8.5 — Business Summary
#
# Write a 200-word business summary of your findings for the e-commerce platform's product team.
#
# **YOUR SUMMARY HERE**

# %% [markdown]
# ---
# ## Grading Rubric
#
# | Task | Points | Criteria |
# |------|--------|----------|
# | Task 1: EDA | 10 | All 5 visualizations present, correct statistics, clear labels |
# | Task 2: Preprocessing | 10 | Pipeline works end-to-end, token counts reported at each stage |
# | Task 3: Classification | 20 | Baseline + improved model, full metrics reported, error analysis |
# | Task 4: ABSA | 15 | 8+ aspects detected, sentiment scored, category comparison |
# | Task 5: NER | 10 | Entity extraction + brand analysis, sentiment by brand |
# | Task 6: Topics | 15 | 8 topics trained, named, category distribution plotted |
# | Task 7: Similarity | 10 | Recommendation function works, tested on 3 products |
# | Task 8: Production | 10 | Dashboard, flagged products, API design, monitoring plan |
# | **Total** | **100** | |
#
# **Bonus:** +5 for zero-shot transformer (Task 3), +5 for Word2Vec similarity (Task 7)
#
# ---
# *NLP Course — Week 10 Capstone*

# %% [markdown]
# ---
# **Author: Lei Wu**
