# %% [markdown]
# # Lecture 19: Practice Exercises
# ### NLP Course 2027 — Week 10
#
# ---
#
# These exercises accompany **Lecture 19: Capstone & Future Trends**.
# Complete each exercise in the provided code cell.

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from transformers import pipeline

# %% [markdown]
# ---
#
# ## Exercise 19.1
#
# Implement a full RAG pipeline using `sentence-transformers` for retrieval and a Hugging Face generative model for answering. Use the course lecture notes as your knowledge base.

# %%
# Exercise 19.1
try:
    from sentence_transformers import SentenceTransformer

    # Knowledge base from course lectures
    knowledge_base = [
        'BERT is a bidirectional transformer model trained on masked language modeling and next sentence prediction.',
        'Fine-tuning means taking a pretrained model and training it on a task-specific labeled dataset for 2-5 epochs.',
        'Named Entity Recognition (NER) identifies named entities (people, organizations, places) in text.',
        'TF-IDF weights terms by frequency in the document divided by their frequency across all documents.',
        'Word2Vec learns word embeddings: king - man + woman = queen.',
        'The transformer attention mechanism allows each token to attend to all other tokens simultaneously.',
        'spaCy is a production-ready NLP library providing tokenization, POS tagging, NER, and dependency parsing.',
        'NLTK (Natural Language Toolkit) is an educational NLP library with access to corpora and parsers.',
        'Sentiment analysis classifies text as positive, negative, or neutral using Naive Bayes, LR, or BERT.',
        'RAG (Retrieval-Augmented Generation) combines a retriever with a generator LLM for grounded answers.',
        'LoRA trains low-rank update matrices instead of all model weights, reducing trainable params by 99%.',
        'WordPiece tokenization splits unknown words into subwords: unbelievable -> un ##believ ##able.',
        'Chunking groups POS-tagged words into noun phrases (NP) and verb phrases (VP).',
        'BM25 is a ranking function for information retrieval using term frequency and inverse document frequency.',
        'LDA (Latent Dirichlet Allocation) discovers latent topics in a document collection.',
    ]

    # YOUR CODE: implement the full RAG pipeline
    # 1. Encode knowledge base with sentence-transformers
    # 2. Given a query, retrieve top-k relevant passages
    # 3. Build a prompt with the retrieved context
    # 4. (Optional) call an LLM API to generate an answer

    def retrieve(query, kb_embeddings, kb_docs, k=3):
        # YOUR CODE
        pass

    def build_rag_prompt(query, retrieved_docs):
        # YOUR CODE
        pass

    test_questions = [
        'What is the difference between BERT and Word2Vec?',
        'How does RAG work?',
        'What is LoRA used for?',
    ]
    for q in test_questions:
        print(f'Q: {q}')
        # YOUR CODE: retrieve and show context
        print()

except ImportError:
    print('Install: pip install sentence-transformers')

# %% [markdown]
# ---
#
# ## Exercise 19.2
#
# Conduct a fairness audit on a sentiment classifier. Test for disparate impact across 5 demographic groups using the demographic parity template.

# %%
# Exercise 19.2
sentiment = pipeline('text-classification',
                     model='distilbert-base-uncased-finetuned-sst-2-english')

# Template-based demographic parity test
templates = [
    'The {group} employee did an excellent job on this project.',
    'The {group} student performed very well on the exam.',
    'The {group} manager made a great decision today.',
    'The {group} doctor treated the patient very effectively.',
    'The {group} engineer solved the problem brilliantly.',
]

demographic_groups = [
    'male', 'female', 'young', 'elderly',
    'White', 'Black', 'Asian', 'Latino', 'Muslim', 'Christian',
]

# YOUR CODE: run each template with each demographic group
# Compute: for each group, what fraction of predictions are POSITIVE?
# Flag any group with >5% deviation from the overall mean as potentially biased

# %% [markdown]
# ---
#
# ## Exercise 19.3
#
# Design a prompt engineering strategy for a task of your choice. Compare zero-shot, few-shot, and chain-of-thought approaches on 20 examples.

# %%
# Exercise 19.3
# Choose a task (e.g., sentiment, NLI, text classification, math word problems)
# Design three prompt strategies

TASK = 'Sentiment classification of customer support tickets'

zero_shot_prompt = """
Classify the sentiment of the following customer support ticket as POSITIVE, NEGATIVE, or NEUTRAL.
Only reply with one word.

Ticket: {text}
Sentiment:"""

few_shot_prompt = """
Classify the sentiment of each support ticket as POSITIVE, NEGATIVE, or NEUTRAL.

Ticket: "My issue was resolved within minutes, great support!"
Sentiment: POSITIVE

Ticket: "I waited 3 hours and no one helped me. Unacceptable."
Sentiment: NEGATIVE

Ticket: "Received confirmation of my request."
Sentiment: NEUTRAL

Ticket: {text}
Sentiment:"""

cot_prompt = """
Analyze this support ticket step by step, then classify sentiment.

Ticket: {text}

Step 1 - Identify emotional words:
Step 2 - Identify the outcome (resolved/unresolved):
Step 3 - Overall sentiment:
Final answer (POSITIVE/NEGATIVE/NEUTRAL):"""

# YOUR CODE: test all three prompts on 20 sample tickets
# If you have access to an LLM API, use it; otherwise use a zero-shot classifier as proxy
# Compare: accuracy, consistency, verbosity
test_tickets = [
    ('Your team solved my billing issue quickly!', 'POSITIVE'),
    ('Three weeks and still no response to my complaint.', 'NEGATIVE'),
    ('I received the tracking number for my order.', 'NEUTRAL'),
    # Add more...
]

for text, true_label in test_tickets[:5]:
    print(f'Text: {text}')
    print(f'True: {true_label}')
    # YOUR CODE: test each prompt strategy
    print()

# %% [markdown]
# ---
#
# ## Exercise 19.4 (Capstone)
#
# Build and deploy an end-to-end NLP application on a domain you care about. Document your design decisions, evaluation, and lessons learned.

# %%
# Exercise 19.4 — Capstone Project

# Use the template below to structure your capstone

PROJECT_TITLE = 'Your Project Title Here'
DOMAIN = 'Your Domain (e.g., healthcare, legal, social media, education)'
PROBLEM = 'Describe the NLP problem you are solving'

# === SECTION 1: Data ===
# dataset_source = '...'  # Where does your data come from?
# dataset_size = ...      # How many examples?
# train_test_split = ...  # e.g., 80/10/10

# === SECTION 2: Pipeline ===
# Define your preprocessing and modeling choices here
class CapstoneNLPPipeline:
    def __init__(self):
        # YOUR CODE: initialize your pipeline
        pass

    def preprocess(self, text):
        # YOUR CODE
        pass

    def predict(self, text):
        # YOUR CODE
        pass

    def evaluate(self, test_data):
        # YOUR CODE: compute appropriate metrics
        pass

# === SECTION 3: Experiments ===
# Try at least 3 approaches and compare
experiments = [
    {'name': 'Baseline (TF-IDF + LR)', 'result': None},
    {'name': 'Deep Learning (LSTM)',   'result': None},
    {'name': 'Fine-tuned BERT',        'result': None},
]

# === SECTION 4: Error Analysis ===
# What types of errors does your best model make?
# failure_cases = [...]

# === SECTION 5: Deployment ===
# Package as a FastAPI service or Gradio demo
print(f'Project: {PROJECT_TITLE}')
print(f'Domain:  {DOMAIN}')
print(f'Problem: {PROBLEM}')

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
