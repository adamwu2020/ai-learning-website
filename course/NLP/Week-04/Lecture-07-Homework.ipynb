# %% [markdown]
# # Lecture 7: Practice Exercises
# ### NLP Course 2027 — Week 04
#
# ---
#
# These exercises accompany **Lecture 7: Information Extraction**.
# Complete each exercise in the provided code cell.

# %%
import re
import nltk
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np

nltk.download('maxent_ne_chunker', quiet=True)
nltk.download('maxent_ne_chunker_tab', quiet=True)
nltk.download('words', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)

# %% [markdown]
# ---
#
# ## Exercise 7.1
#
# Extend the pattern-based relation extractor to find WORKS_FOR relations (e.g., 'X works at Y', 'X is employed by Y').

# %%
# Exercise 7.1
def extract_works_for(text):
    """
    Extract WORKS_FOR relations: (person, organization)
    Handle patterns like: 'X works at Y', 'X is employed by Y', 'X joined Y'
    """
    # YOUR CODE: add patterns for WORKS_FOR relations
    patterns = [
        # (regex_pattern, relation_type)
    ]
    results = []
    # ... apply patterns ...
    return results

test_text = """
John Smith works at Google. Jane Doe is employed by Microsoft.
Bob Johnson joined Apple last year. Sarah Lee is a researcher at MIT.
"""
for rel in extract_works_for(test_text):
    print(rel)

# %% [markdown]
# ---
#
# ## Exercise 7.2
#
# Compare RAKE and TF-IDF keyphrase extraction on a news article. Which produces better keyphrases?

# %%
# Exercise 7.2
# Use the rake_keywords and tfidf_keyphrases functions from the lecture (reimplement or copy)

article = """
Artificial intelligence researchers at Stanford University have developed a new
deep learning model that can diagnose rare diseases from medical images with
95% accuracy. The model, trained on over one million patient records, outperforms
human specialists in identifying specific genetic disorders. The research team,
led by Professor Sarah Chen, plans to conduct clinical trials next year.
"""

# YOUR CODE: apply both RAKE and TF-IDF keyphrase extraction
# Compare and discuss the results

# %% [markdown]
# ---
#
# ## Exercise 7.3
#
# Build an event extractor that identifies who did what, when, and where from news sentences.

# %%
# Exercise 7.3
def extract_events(text):
    """
    Extract events as {who, action, when, where} dicts.
    Use regex patterns or NER + dependency heuristics.
    """
    # YOUR CODE
    pass

news = """
Google announced a new AI model in San Francisco on Monday.
Tesla CEO Elon Musk launched the Cybertruck in Texas last November.
The World Health Organization declared a public health emergency in Geneva on Tuesday.
"""
events = extract_events(news)
for event in events:
    print(event)

# %% [markdown]
# ---
#
# ## Exercise 7.4
#
# Implement a simple coreference resolver that replaces pronouns (he, she, they) with the most recent matching named entity.

# %%
# Exercise 7.4
def simple_coref_resolve(text):
    """
    Replace pronouns (he, she, they) with the most recently mentioned
    named entity of the appropriate type (PERSON for he/she).
    """
    # YOUR CODE
    pass

text = """Barack Obama was born in Hawaii. He served as president for eight years.
Michelle Obama is a lawyer. She wrote a bestselling memoir.
The Obamas live in Washington D.C. They are very influential."""

resolved = simple_coref_resolve(text)
print(resolved)

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
