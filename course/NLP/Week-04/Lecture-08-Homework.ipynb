# %% [markdown]
# # Lecture 8: Practice Exercises
# ### NLP Course 2027 — Week 04
#
# ---
#
# These exercises accompany **Lecture 8: Real-World NLP Pipeline Design**.
# Complete each exercise in the provided code cell.

# %%
import re
import string
import time
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer

nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

# %% [markdown]
# ---
#
# ## Exercise 8.1
#
# Build a pipeline for a specific domain (medical reports, legal documents, or financial news). What preprocessing decisions differ from general text?

# %%
# Exercise 8.1
# Choose a domain and build a specialized preprocessing pipeline.
# Document your design decisions with comments.

class DomainNLPPipeline:
    """Specialized NLP pipeline for [YOUR CHOSEN DOMAIN]."""

    def __init__(self):
        # YOUR CODE: initialize with domain-specific settings
        pass

    def process(self, text):
        # YOUR CODE: implement domain-specific preprocessing
        pass

# Test with sample domain text
sample_text = "YOUR DOMAIN SAMPLE HERE"
pipeline = DomainNLPPipeline()
print(pipeline.process(sample_text))

# %% [markdown]
# ---
#
# ## Exercise 8.2
#
# Implement a `LanguageDetector` class that uses character n-grams to distinguish English from French and Spanish.

# %%
# Exercise 8.2
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

class LanguageDetector:
    """Detect language using character n-gram features."""

    TRAIN_DATA = [
        # (text, language)
        ('The quick brown fox jumps over the lazy dog', 'en'),
        ('Natural language processing is fascinating', 'en'),
        ('Machine learning models learn from data', 'en'),
        ('Le renard brun rapide saute par-dessus le chien paresseux', 'fr'),
        ('Le traitement du langage naturel est fascinant', 'fr'),
        ('Les modeles d apprentissage automatique apprennent des donnees', 'fr'),
        ('El rapido zorro marron salta sobre el perro perezoso', 'es'),
        ('El procesamiento del lenguaje natural es fascinante', 'es'),
        ('Los modelos de aprendizaje automatico aprenden de los datos', 'es'),
    ]

    def __init__(self):
        # YOUR CODE: train a character n-gram classifier
        pass

    def detect(self, text):
        # YOUR CODE: predict language
        pass

detector = LanguageDetector()
test_texts = [
    'This is an English sentence.',
    'Ceci est une phrase en francais.',
    'Esta es una frase en espanol.',
]
for text in test_texts:
    print(f'{detector.detect(text)}: {text}')

# %% [markdown]
# ---
#
# ## Exercise 8.3
#
# Benchmark your `NLPPipeline` on 10,000 documents. How many documents/second can it process? Where are the bottlenecks?

# %%
# Exercise 8.3
import time
from nltk.corpus import reuters
nltk.download('reuters', quiet=True)

# Load some documents to benchmark
docs = [reuters.raw(fid) for fid in reuters.fileids()[:1000]]
print(f'Loaded {len(docs)} documents')

# YOUR CODE: implement and run a pipeline, measure throughput
# Profile which stage is the bottleneck: cleaning, tokenizing, or normalizing

# %% [markdown]
# ---
#
# ## Exercise 8.4
#
# Implement back-translation augmentation (EN->FR->EN) using the Hugging Face translation pipeline.

# %%
# Exercise 8.4
from transformers import pipeline

def back_translate(text, src_lang='en', pivot_lang='fr'):
    """
    Translate text: src -> pivot -> src
    Uses Helsinki-NLP translation models.
    """
    # YOUR CODE: translate EN->FR then FR->EN
    # en_to_fr = pipeline('translation_en_to_fr', model='Helsinki-NLP/opus-mt-en-fr')
    # fr_to_en = pipeline('translation_fr_to_en', model='Helsinki-NLP/opus-mt-fr-en')
    pass

originals = [
    'The researchers published an interesting paper about machine learning.',
    'Natural language processing enables computers to understand text.',
]
for text in originals:
    augmented = back_translate(text)
    print(f'Original:  {text}')
    print(f'Augmented: {augmented}')
    print()

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
