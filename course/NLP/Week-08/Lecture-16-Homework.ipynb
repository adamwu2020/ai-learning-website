# %% [markdown]
# # Lecture 16: Practice Exercises
# ### NLP Course 2027 — Week 08
#
# ---
#
# These exercises accompany **Lecture 16: NLP Applications & Case Studies**.
# Complete each exercise in the provided code cell.

# %%
import math
import numpy as np
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)

# %% [markdown]
# ---
#
# ## Exercise 16.1
#
# Implement BM25 retrieval for a document collection of your choice. Evaluate against TF-IDF cosine similarity on 10 queries.

# %%
# Exercise 16.1
# Copy or reimplement BM25 from the lecture
# Then compare with TF-IDF on 10 queries

# Use a corpus of your choice (e.g., Reuters news, Wikipedia snippets)
from nltk.corpus import reuters
nltk.download('reuters', quiet=True)

doc_ids = reuters.fileids()[:100]
corpus = [reuters.raw(fid) for fid in doc_ids]

# YOUR CODE: implement BM25 and TF-IDF retrieval
# Define 10 test queries
# Compare the top-3 results from each method
queries = [
    'oil price increase OPEC',
    'stock market crash Wall Street',
    'trade deficit import export',
    'interest rate Federal Reserve',
    'gold silver commodity price',
]

# YOUR CODE: run both retrievers and compare results

# %% [markdown]
# ---
#
# ## Exercise 16.2
#
# Train LDA on the 20 Newsgroups dataset (`sklearn.datasets.fetch_20newsgroups`). Do the topics align with the 20 known categories?

# %%
# Exercise 16.2
from sklearn.datasets import fetch_20newsgroups
import gensim
from gensim import corpora
from gensim.models import LdaModel

data = fetch_20newsgroups(subset='train', remove=('headers', 'footers', 'quotes'))
print(f'Loaded {len(data.data)} documents across {len(data.target_names)} categories')
print('Categories:', data.target_names[:5], '...')

# YOUR CODE: preprocess docs, train LDA with K=20 topics
# For each topic, check if its top words correspond to any of the 20 newsgroup categories
# Report: which categories are easiest/hardest to identify from topic words?

# %% [markdown]
# ---
#
# ## Exercise 16.3
#
# Compare extractive TextRank vs abstractive BART summarization on 5 news articles. Which is more faithful? Which is more concise?

# %%
# Exercise 16.3
from transformers import pipeline

articles = [
    # Add 5 news articles here (or fetch from a news source)
    """Scientists at MIT have developed a new battery technology that could
    revolutionize electric vehicles. The new lithium-silicon battery offers
    three times the energy density of conventional lithium-ion batteries.
    The technology could allow EVs to travel up to 900 miles on a single charge.
    Researchers expect the technology to reach commercial production within five years.
    The breakthrough was published in the journal Nature Energy.""",
    # Add 4 more articles...
]

# YOUR CODE: apply TextRank extractive summarizer (implement or import)
# and BART abstractive summarizer to each article
# Compare: compression ratio, readability, faithfulness
# Compute: how many sentences/words in original vs summary?

# %% [markdown]
# ---
#
# ## Exercise 16.4
#
# Build a movie recommendation system using TF-IDF on plot descriptions from a MovieLens or IMDb dataset.

# %%
# Exercise 16.4
# Use this sample movie catalog or download a real dataset
movies = [
    {'title': 'The Matrix', 'genre': 'sci-fi',
     'plot': 'A hacker discovers reality is a simulation and joins a rebellion against machines.'},
    {'title': 'Inception', 'genre': 'sci-fi',
     'plot': 'A thief who enters dreams to steal secrets is given the task of planting an idea.'},
    {'title': 'Interstellar', 'genre': 'sci-fi',
     'plot': 'Astronauts travel through a wormhole near Saturn to find a new home for humanity.'},
    {'title': 'The Dark Knight', 'genre': 'action',
     'plot': 'Batman must accept one of the greatest psychological and physical tests of his ability to fight injustice.'},
    {'title': 'Pulp Fiction', 'genre': 'crime',
     'plot': 'The lives of two mob hitmen, a boxer, and a pair of diner bandits interweave in tales of violence.'},
    {'title': 'The Shawshank Redemption', 'genre': 'drama',
     'plot': 'Two imprisoned men bond over a number of years, finding solace and redemption through acts of decency.'},
    {'title': 'Avengers: Endgame', 'genre': 'action',
     'plot': 'The Avengers and their allies must be willing to sacrifice all in order to defeat Thanos.'},
    {'title': 'Arrival', 'genre': 'sci-fi',
     'plot': 'A linguist works with the military to communicate with alien life forms that arrive on Earth.'},
]

# YOUR CODE: build TF-IDF recommendation system on plot descriptions
# Given a movie title, recommend 3 similar movies
# Test: recommend movies similar to 'The Matrix' and 'Pulp Fiction'

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
