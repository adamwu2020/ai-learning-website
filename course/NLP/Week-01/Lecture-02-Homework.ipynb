# %% [markdown]
# # Lecture 2: Practice Exercises
# ### NLP Course 2027 — Week 01
#
# ---
#
# These exercises accompany **Lecture 2: Python for Text Processing**.
# Complete each exercise in the provided code cell.

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.tokenize import TweetTokenizer, RegexpTokenizer
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk import FreqDist

nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

# %% [markdown]
# ---
#
# ## Exercise 2.1
#
# Write `word_char_stats(text)` returning: total_chars, total_words, unique_words, avg_word_length, longest_word.

# %%
# Exercise 2.1 starter
def word_char_stats(text):
    tokens = word_tokenize(text)
    words = [t for t in tokens if t.isalpha()]
    return {
        'total_chars': len(text),
        'total_words': len(words),
        'unique_words': len(set(w.lower() for w in words)),
        # YOUR CODE: add avg_word_length and longest_word
    }

print(word_char_stats('Natural Language Processing with Python is a great NLP textbook.'))

# %% [markdown]
# ---
#
# ## Exercise 2.2
#
# Compare tokenization of `"I can't believe it's 5 o'clock!"` using `split()`, `word_tokenize()`, and `RegexpTokenizer(r'\w+')`. Which handles contractions best?

# %%
# Exercise 2.2
text = "I can't believe it's 5 o'clock!"

# YOUR CODE: tokenize using all three methods and compare

# %% [markdown]
# ---
#
# ## Exercise 2.3
#
# Load the Reuters corpus (`nltk.corpus.reuters`) and find the 20 most common content words across all documents.

# %%
# Exercise 2.3
import nltk
from nltk.corpus import reuters
nltk.download('reuters', quiet=True)

# YOUR CODE: load Reuters, remove stopwords, find top 20 content words

# %% [markdown]
# ---
#
# ## Exercise 2.4
#
# Build a `TextPreprocessor` class with `__init__` parameters (lowercase, remove_punct, remove_stopwords, stem) and a `process(text)` method.

# %%
# Exercise 2.4
class TextPreprocessor:
    def __init__(self, lowercase=True, remove_punct=True, remove_stopwords=True, stem=False):
        # YOUR CODE: store parameters and initialize any needed resources
        pass

    def process(self, text):
        # YOUR CODE: implement the preprocessing pipeline
        pass

# Test your implementation
tp = TextPreprocessor(lowercase=True, remove_punct=True, remove_stopwords=True, stem=True)
print(tp.process('The researchers are studying NLP models and evaluating performance!'))

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
