# %% [markdown]
# # Lecture 1: Practice Exercises
# ### NLP Course 2027 — Week 01
#
# ---
#
# These exercises accompany **Lecture 1: Introduction to NLP & Text Processing**.
# Complete each exercise in the provided code cell.
#
# **Primary Reference:** *Natural Language Processing with Python* (Bird, Klein & Loper), Chapter 1

# %%
# Setup — run this cell first
import nltk

for pkg in ['book', 'punkt', 'punkt_tab', 'stopwords', 'wordnet',
            'averaged_perceptron_tagger', 'maxent_ne_chunker', 'words']:
    nltk.download(pkg, quiet=True)

from nltk.book import text1, text2, text3, text4, text5, text6
print('Ready!')

# %% [markdown]
# ---
# ## Exercise 1.1 — Lexical Diversity
#
# Write a function `lexical_diversity(text)` that computes the ratio of unique words to total words. Compare all six NLTK texts.

# %%
def lexical_diversity(text):
    """Ratio of unique words to total words."""
    # YOUR CODE HERE
    pass


texts = {
    'Moby Dick':           text1,
    'Sense & Sensibility': text2,
    'Genesis':             text3,
    'Inaugural Addresses': text4,
    'Chat Corpus':         text5,
    'Monty Python':        text6,
}

for name, t in texts.items():
    score = lexical_diversity(t)
    print(f'{name}: {score}')

# %% [markdown]
# ---
# ## Exercise 1.2 — Dispersion Plot
#
# Use `text4.dispersion_plot(['citizens', 'democracy', 'freedom', 'war'])` on the Inaugural Address corpus. What historical trends do you observe?

# %%
text4.dispersion_plot(['citizens', 'democracy', 'freedom', 'war'])

# YOUR OBSERVATIONS HERE (in a comment or print statement):
# e.g., print("Observation: ...")

# %% [markdown]
# ---
# ## Exercise 1.3 — Long Repeated Words
#
# Find all words in `text1` (Moby Dick) longer than 15 characters that appear more than once.

# %%
# YOUR CODE HERE

# %% [markdown]
# ---
# ## Exercise 1.4 — Content Word Frequency
#
# Build a frequency distribution for `text6` (Monty Python). What are the most common content words (non-stopwords)?

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))

# YOUR CODE HERE

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
