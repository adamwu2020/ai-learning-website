# %% [markdown]
# # Lecture 10: Practice Exercises
# ### NLP Course 2027 — Week 05
#
# ---
#
# These exercises accompany **Lecture 10: Deep Learning for Text Classification**.
# Complete each exercise in the provided code cell.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import numpy as np
from collections import Counter
import nltk
from nltk.corpus import movie_reviews
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

nltk.download('movie_reviews', quiet=True)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f'Using device: {device}')

# %% [markdown]
# ---
#
# ## Exercise 10.1
#
# Implement and train the `TextCNN` model on the movie reviews dataset. Compare accuracy with LSTM.

# %%
# Exercise 10.1
# Copy or reimplement TextCNN from the lecture, then train it on movie reviews.
# Report final test accuracy and compare with the lecture's LSTM result.

class TextCNN(nn.Module):
    def __init__(self, vocab_size, embed_dim, num_filters, filter_sizes, num_classes, dropout=0.5):
        super().__init__()
        # YOUR CODE: implement TextCNN architecture
        pass

    def forward(self, x):
        # YOUR CODE
        pass

# YOUR CODE: load movie reviews, build vocab, train TextCNN, evaluate

# %% [markdown]
# ---
#
# ## Exercise 10.2
#
# Add bidirectional LSTM and attention pooling to the classifier. Does it improve performance?

# %%
# Exercise 10.2
class BiLSTMWithAttention(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, num_classes, dropout=0.3):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True, bidirectional=True)
        self.dropout = nn.Dropout(dropout)
        # YOUR CODE: add attention mechanism
        # Attention: compute score for each hidden state, softmax, weighted sum
        self.classifier = nn.Linear(hidden_dim * 2, num_classes)

    def attention(self, lstm_output):
        # YOUR CODE: implement attention pooling
        # Return weighted sum of lstm_output
        pass

    def forward(self, x):
        # YOUR CODE
        pass

# %% [markdown]
# ---
#
# ## Exercise 10.3
#
# Experiment with different hyperparameters: embedding size (50, 100, 200), hidden size, dropout rate. Plot validation accuracy vs epochs.

# %%
# Exercise 10.3
import matplotlib.pyplot as plt

# YOUR CODE: run experiments with different hyperparameter settings
# Track validation accuracy per epoch for each configuration
# Plot the results

hyperparams = [
    {'embed_dim': 50,  'hidden_dim': 64,  'dropout': 0.3, 'label': 'small'},
    {'embed_dim': 100, 'hidden_dim': 128, 'dropout': 0.3, 'label': 'medium'},
    {'embed_dim': 200, 'hidden_dim': 256, 'dropout': 0.5, 'label': 'large'},
]

# YOUR CODE: train each configuration and plot val_accuracy vs epoch

# %% [markdown]
# ---
#
# ## Exercise 10.4
#
# Load pretrained GloVe embeddings and initialize the embedding layer. Does it speed up training?

# %%
# Exercise 10.4
import gensim.downloader

def load_glove_embeddings(vocab, embed_dim=50):
    """
    Load GloVe embeddings for words in vocab.
    Returns an embedding matrix of shape (vocab_size, embed_dim).
    """
    # YOUR CODE: use gensim.downloader.load('glove-wiki-gigaword-50')
    # or load from a local file if downloaded
    pass

# YOUR CODE: initialize model embedding layer with GloVe weights
# Compare convergence speed vs random initialization

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
