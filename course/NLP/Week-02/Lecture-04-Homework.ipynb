# %% [markdown]
# # Lecture 4: Practice Exercises
# ### NLP Course 2027 — Week 02
#
# ---
#
# These exercises accompany **Lecture 4: Regular Expressions & Structured Text**.
# Complete each exercise in the provided code cell.

# %%
import re
import nltk
from nltk.tokenize import RegexpTokenizer
from nltk import RegexpParser, pos_tag, word_tokenize

nltk.download('punkt', quiet=True)
nltk.download('averaged_perceptron_tagger', quiet=True)
nltk.download('averaged_perceptron_tagger_eng', quiet=True)

# %% [markdown]
# ---
#
# ## Exercise 4.1
#
# Write regex to extract all phone numbers from a text. Handle formats: (123) 456-7890, 123-456-7890, +1 123 456 7890.

# %%
# Exercise 4.1 starter
def extract_phone_numbers(text):
    """
    Extract phone numbers from text.
    Handles: (123) 456-7890, 123-456-7890, +1 123 456 7890
    """
    # YOUR CODE HERE - write the regex pattern
    pattern = r'YOUR_PATTERN_HERE'
    return re.findall(pattern, text)

test = 'Call (415) 555-1234 or 800-555-0199 or +1 212 555 0147 for support.'
print(extract_phone_numbers(test))

# %% [markdown]
# ---
#
# ## Exercise 4.2
#
# Write a function `count_pattern_matches(text, pattern)` that counts overlapping regex matches using `re.finditer`.

# %%
# Exercise 4.2
def count_pattern_matches(text, pattern):
    # YOUR CODE: use re.finditer to count overlapping matches
    pass

# Test: count overlapping occurrences of 'aa' in 'aaaa' (should be 3)
print(count_pattern_matches('aaaa', 'aa'))
print(count_pattern_matches('the cat sat on the mat', r'\bthe\b'))

# %% [markdown]
# ---
#
# ## Exercise 4.3
#
# Build a regex-based email classifier: given an email body, extract action items (sentences containing 'please', 'need to', 'must', 'should').

# %%
# Exercise 4.3
def extract_action_items(email_body):
    # YOUR CODE: find sentences containing action keywords
    pass

email = """
Hi team,
The report looks good overall. Please review the final section by Friday.
I need to schedule a meeting this week.
The budget must be approved before launch.
You should coordinate with the design team.
Thanks for your hard work!
"""
actions = extract_action_items(email)
for a in actions:
    print('-', a)

# %% [markdown]
# ---
#
# ## Exercise 4.4
#
# Using `RegexpParser`, write a grammar to extract Verb Phrases (VP) from sentences. Test on 3 different sentences.

# %%
# Exercise 4.4
# YOUR CODE: define a VP grammar and extract verb phrases from 3 sentences
grammar = r"""
  NP: {<DT>?<JJ.*>*<NN.*>+}
  VP: {YOUR_VP_PATTERN_HERE}
"""

sentences = [
    'The researcher published an important paper last year.',
    'Students are learning natural language processing.',
    'The model correctly predicted the sentiment of the review.',
]

for sent in sentences:
    # YOUR CODE: parse and print VP chunks
    pass

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
