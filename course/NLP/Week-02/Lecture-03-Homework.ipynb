# %% [markdown]
# # Lecture 3: Practice Exercises
# ### NLP Course 2027 — Week 02
#
# ---
#
# These exercises accompany **Lecture 3: Corpus Access & Lexical Resources**.
# Complete each exercise in the provided code cell.

# %%
import nltk
from nltk.corpus import gutenberg, brown, reuters, inaugural, stopwords
from nltk.corpus import wordnet as wn
from nltk import FreqDist, ConditionalFreqDist

nltk.download('gutenberg', quiet=True)
nltk.download('brown', quiet=True)
nltk.download('reuters', quiet=True)
nltk.download('inaugural', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)

# %% [markdown]
# ---
#
# ## Exercise 3.1
#
# Compute the average sentence length (in words) for each Gutenberg text. Which author writes longest sentences?

# %%
# Exercise 3.1
# YOUR CODE: compute average sentence length for each Gutenberg text

# %% [markdown]
# ---
#
# ## Exercise 3.2
#
# Using the Brown corpus, compare the 20 most common words in 'news' vs 'romance' categories. What differences do you see?

# %%
# Exercise 3.2
# YOUR CODE: compare top 20 words in 'news' vs 'romance'

# %% [markdown]
# ---
#
# ## Exercise 3.3
#
# In WordNet, find all hyponyms of 'vehicle'. How many are there?

# %%
# Exercise 3.3
# YOUR CODE: find all hyponyms of 'vehicle' using WordNet
# Hint: use .hyponyms() recursively or .closure(lambda s: s.hyponyms())

# %% [markdown]
# ---
#
# ## Exercise 3.4
#
# Write a function `find_antonyms(word)` that returns all antonyms of a given word using WordNet lemmas.

# %%
# Exercise 3.4 starter
def find_antonyms(word):
    antonyms = []
    for syn in wn.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.append(lemma.antonyms()[0].name())
    return list(set(antonyms))

for w in ['good', 'happy', 'fast', 'love']:
    print(f'{w}: {find_antonyms(w)}')

# %% [markdown]
# ---
# **Author: Lei Wu | © 2026 Lei Wu. All rights reserved. Unauthorized use is prohibited.**
